# %%
import numpy as np
from numpy import outer, trace, dot, vdot, pi, log2, exp, sin, cos, sqrt, sign, diag, linspace, arange, array, inf, zeros, eye, arccos, arcsin, arctan, mean, std, concatenate, kron, sign, ceil, log, unique
import pickle
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rcParams['font.family']='serif'
matplotlib.rcParams['axes.unicode_minus']=False
matplotlib.rcParams.update({'font.size': 20})
matplotlib.rc('text', usetex=True)

# %%
n_inp = 8
n_copies= 1
n_runs = 10
w_ls = 1
w_var = 1e-4
ham_name = "ising_ham"
# p = 1

# %%
n_meas_list = [0]
ansatz_name = "qcnn_circ"
ansatz_info = ""

path = f"/home/investigator/Work/qcnn-var/Results/ising_ham/"
info = f"{ham_name}-{ansatz_name}{ansatz_info}-" + ("n=%d-c=%d-m=%s-r=%d-w_ls=%.1f-w_var=%.4f" %(n_inp, n_copies, n_meas_list, n_runs, w_ls, w_var)).replace(" ", "")

with open(path + info + ".dict", 'rb') as fp:
    data_dict_loaded = pickle.load(fp)

labels_test = data_dict_loaded["labels_test"]
expecs_list_qcnn_0 = data_dict_loaded["expecs_list"]
expecs_der_list_qcnn_0 = data_dict_loaded["expecs_der_list"]
disps_list_qcnn_0 = data_dict_loaded["disps_list"]
CFIs_list_qcnn_0 = data_dict_loaded["CFIs_list"]
QFIs = data_dict_loaded["QFIs"]

bias_mean_qcnn_0 = np.mean((labels_test - expecs_list_qcnn_0)**2, axis=0)
bias_std_qcnn_0 = np.std((labels_test - expecs_list_qcnn_0)**2, axis=0)
disps_red_mean_qcnn_0 = np.mean(disps_list_qcnn_0/expecs_der_list_qcnn_0**2, axis=0)
disps_red_std_qcnn_0 = np.std(disps_list_qcnn_0/expecs_der_list_qcnn_0**2, axis=0)
CCRBs_mean_qcnn_0 = np.mean(1/CFIs_list_qcnn_0, axis=0)
CCRBs_std_qcnn_0 = np.std(1/CFIs_list_qcnn_0, axis=0)
# Out:
# /tmp/ipykernel_3623944/3245593353.py:9: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data_dict_loaded = pickle.load(fp)

# %%
n_meas_list = [0, 4]
ansatz_name = "qcnn_circ"
ansatz_info = ""

path = f"/home/investigator/Work/qcnn-var/Results/ising_ham/"
info = f"{ham_name}-{ansatz_name}{ansatz_info}-" + ("n=%d-c=%d-m=%s-r=%d-w_ls=%.1f-w_var=%.4f" %(n_inp, n_copies, n_meas_list, n_runs, w_ls, w_var)).replace(" ", "")

with open(path + info + ".dict", 'rb') as fp:
    data_dict_loaded = pickle.load(fp)

labels_test = data_dict_loaded["labels_test"]
expecs_list_qcnn_04 = data_dict_loaded["expecs_list"]
expecs_der_list_qcnn_04 = data_dict_loaded["expecs_der_list"]
disps_list_qcnn_04 = data_dict_loaded["disps_list"]
CFIs_list_qcnn_04 = data_dict_loaded["CFIs_list"]
QFIs = data_dict_loaded["QFIs"]

bias_mean_qcnn_04 = np.mean((labels_test - expecs_list_qcnn_04)**2, axis=0)
bias_std_qcnn_04 = np.std((labels_test - expecs_list_qcnn_04)**2, axis=0)
disps_red_mean_qcnn_04 = np.mean(disps_list_qcnn_04/expecs_der_list_qcnn_04**2, axis=0)
disps_red_std_qcnn_04 = np.std(disps_list_qcnn_04/expecs_der_list_qcnn_04**2, axis=0)
CCRBs_mean_qcnn_04 = np.mean(1/CFIs_list_qcnn_04, axis=0)
CCRBs_std_qcnn_04 = np.std(1/CFIs_list_qcnn_04, axis=0)
# Out:
# /tmp/ipykernel_3623944/1998268730.py:9: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data_dict_loaded = pickle.load(fp)

# %%
n_meas_list = [0]
ansatz_name = "hea_rzz"
ansatz_info = "-l=5"

path = f"/home/investigator/Work/qcnn-var/Results/ising_ham/"
info = f"{ham_name}-{ansatz_name}{ansatz_info}-" + ("n=%d-c=%d-m=%s-r=%d-w_ls=%.1f-w_var=%.4f" %(n_inp, n_copies, n_meas_list, n_runs, w_ls, w_var)).replace(" ", "")

with open(path + info + ".dict", 'rb') as fp:
    data_dict_loaded = pickle.load(fp)

labels_test = data_dict_loaded["labels_test"]
expecs_list_hea_0 = data_dict_loaded["expecs_list"]
expecs_der_list_hea_0 = data_dict_loaded["expecs_der_list"]
disps_list_hea_0 = data_dict_loaded["disps_list"]
CFIs_list_hea_0 = data_dict_loaded["CFIs_list"]
QFIs = data_dict_loaded["QFIs"]

bias_mean_hea_0 = np.mean((labels_test - expecs_list_hea_0)**2, axis=0)
bias_std_hea_0 = np.std((labels_test - expecs_list_hea_0)**2, axis=0)
disps_red_mean_hea_0 = np.mean(disps_list_hea_0/expecs_der_list_hea_0**2, axis=0)
disps_red_std_hea_0 = np.std(disps_list_hea_0/expecs_der_list_hea_0**2, axis=0)
CCRBs_mean_hea_0 = np.mean(1/CFIs_list_hea_0, axis=0)
CCRBs_std_hea_0 = np.std(1/CFIs_list_hea_0, axis=0)
# Out:
# /tmp/ipykernel_3623944/1924519760.py:9: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data_dict_loaded = pickle.load(fp)

# %%
n_meas_list = [0, 1]
ansatz_name = "hea_rzz"
ansatz_info = "-l=5"

path = f"/home/investigator/Work/qcnn-var/Results/ising_ham/"
info = f"{ham_name}-{ansatz_name}{ansatz_info}-" + ("n=%d-c=%d-m=%s-r=%d-w_ls=%.1f-w_var=%.4f" %(n_inp, n_copies, n_meas_list, n_runs, w_ls, w_var)).replace(" ", "")

with open(path + info + ".dict", 'rb') as fp:
    data_dict_loaded = pickle.load(fp)

labels_test = data_dict_loaded["labels_test"]
expecs_list_hea_01 = data_dict_loaded["expecs_list"]
expecs_der_list_hea_01 = data_dict_loaded["expecs_der_list"]
disps_list_hea_01 = data_dict_loaded["disps_list"]
CFIs_list_hea_01 = data_dict_loaded["CFIs_list"]
QFIs = data_dict_loaded["QFIs"]

bias_mean_hea_01 = np.mean((labels_test - expecs_list_hea_01)**2, axis=0)
bias_std_hea_01 = np.std((labels_test - expecs_list_hea_01)**2, axis=0)
disps_red_mean_hea_01 = np.mean(disps_list_hea_01/expecs_der_list_hea_01**2, axis=0)
disps_red_std_hea_01 = np.std(disps_list_hea_01/expecs_der_list_hea_01**2, axis=0)
CCRBs_mean_hea_01 = np.mean(1/CFIs_list_hea_01, axis=0)
CCRBs_std_hea_01 = np.std(1/CFIs_list_hea_01, axis=0)
# Out:
# /tmp/ipykernel_3623944/2111538800.py:9: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data_dict_loaded = pickle.load(fp)

# %%
n_meas_list = [0, 1, 2, 3]
ansatz_name = "hea_rzz"
ansatz_info = "-l=5"

path = f"/home/investigator/Work/qcnn-var/Results/ising_ham/"
info = f"{ham_name}-{ansatz_name}{ansatz_info}-" + ("n=%d-c=%d-m=%s-r=%d-w_ls=%.1f-w_var=%.4f" %(n_inp, n_copies, n_meas_list, n_runs, w_ls, w_var)).replace(" ", "")

with open(path + info + ".dict", 'rb') as fp:
    data_dict_loaded = pickle.load(fp)

labels_test = data_dict_loaded["labels_test"]
expecs_list_hea_0123 = data_dict_loaded["expecs_list"]
expecs_der_list_hea_0123 = data_dict_loaded["expecs_der_list"]
disps_list_hea_0123 = data_dict_loaded["disps_list"]
CFIs_list_hea_0123 = data_dict_loaded["CFIs_list"]
QFIs = data_dict_loaded["QFIs"]

bias_mean_hea_0123 = np.mean((labels_test - expecs_list_hea_0123)**2, axis=0)
bias_std_hea_0123 = np.std((labels_test - expecs_list_hea_0123)**2, axis=0)
disps_red_mean_hea_0123 = np.mean(disps_list_hea_0123/expecs_der_list_hea_0123**2, axis=0)
disps_red_std_hea_0123 = np.std(disps_list_hea_0123/expecs_der_list_hea_0123**2, axis=0)
CCRBs_mean_hea_0123 = np.mean(1/CFIs_list_hea_0123, axis=0)
CCRBs_std_hea_0123 = np.std(1/CFIs_list_hea_0123, axis=0)
# Out:
# /tmp/ipykernel_3623944/1030760346.py:9: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data_dict_loaded = pickle.load(fp)

# %%
file_info = r"%s-n=%d-c=%d-m=%s-w_ls=%.1f-w_var=%.4f" %(ham_name, n_inp, n_copies, "[(0),(0,4),4]", w_ls, w_var)

plt.figure(figsize=(6, 4))
p_qcnn_0 = plt.plot(labels_test, bias_mean_qcnn_0, color="tab:blue", linewidth=2)
p_qcnn_04 = plt.plot(labels_test, bias_mean_qcnn_04, color="tab:red", linewidth=2)
# p_hea_0 = plt.plot(labels_test, bias_mean_hea_0, color="tab:orange", linewidth=2)
p_hea_01 = plt.plot(labels_test, bias_mean_hea_01, color="gold", linewidth=2)
# p_hea_0123 = plt.plot(labels_test, bias_mean_hea_0123, color="tab:purple", linewidth=2)
f_qcnn_0 = plt.fill_between(labels_test, bias_mean_qcnn_0 - bias_std_qcnn_0, bias_mean_qcnn_0 + bias_std_qcnn_0, alpha=0.35, color="tab:blue")
f_qcnn_04 = plt.fill_between(labels_test, bias_mean_qcnn_04 - bias_std_qcnn_04, bias_mean_qcnn_04 + bias_std_qcnn_04, alpha=0.35, color="tab:red")
# f_hea_0 = plt.fill_between(labels_test, bias_mean_hea_0 - bias_std_hea_0, bias_mean_hea_0 + bias_std_hea_0, alpha=0.35, color="tab:orange")
f_hea_01 = plt.fill_between(labels_test, bias_mean_hea_01 - bias_std_hea_01, bias_mean_hea_01 + bias_std_hea_01, alpha=0.35, color="gold")
# f_hea_0123 = plt.fill_between(labels_test, bias_mean_hea_0123 - bias_std_hea_0123, bias_mean_hea_0123 + bias_std_hea_0123, alpha=0.35, color="tab:purple")
plt.xlabel(r"$h$")
plt.ylabel(r"$(\mathsf{h} - h)^2$")
plt.grid()
plt.legend([(p_qcnn_0[0], f_qcnn_0), (p_qcnn_04[0], f_qcnn_04), (p_hea_01[0], f_hea_01)], [r"$m=1$, QCNN", r"$m=2$, QCNN", r"$m=2$, HEA"], framealpha=1)
plt.tight_layout()
# plt.savefig(path + "bfgs-" + file_info + "-mean-est.pdf", transparent=True, bbox_inches='tight')
plt.show()

plt.figure(figsize=(6, 4))
p_qcnn_0 = plt.plot(labels_test, disps_red_mean_qcnn_0, linewidth=2, zorder=10)
p_qcnn_04 = plt.plot(labels_test, disps_red_mean_qcnn_04, linewidth=2, color="tab:red", zorder=10)
# p_hea_0 = plt.plot(labels_test, disps_red_mean_hea_0, linewidth=2, color="tab:orange", zorder=10)
p_hea_01 = plt.plot(labels_test, disps_red_mean_hea_01, linewidth=2, color="gold", zorder=10)
# p_hea_0123 = plt.plot(labels_test, disps_red_mean_hea_0123, linewidth=2, color="tab:purple", zorder=10)
f_qcnn_0 = plt.fill_between(labels_test, disps_red_mean_qcnn_0 - disps_red_std_qcnn_0, disps_red_mean_qcnn_0 + disps_red_std_qcnn_0, alpha=0.35, zorder=9)
f_qcnn_04 = plt.fill_between(labels_test, disps_red_mean_qcnn_04 - disps_red_std_qcnn_04, disps_red_mean_qcnn_04 + disps_red_std_qcnn_04, alpha=0.35, color="tab:red", zorder=9)
# f_hea_0 = plt.fill_between(labels_test, disps_red_mean_hea_0 - disps_red_std_hea_0, disps_red_mean_hea_0 + disps_red_std_hea_0, alpha=0.35, color="tab:orange", zorder=9)
f_hea_01 = plt.fill_between(labels_test, disps_red_mean_hea_01 - disps_red_std_hea_01, disps_red_mean_hea_01 + disps_red_std_hea_01, alpha=0.35, color="gold", zorder=9)
# f_hea_0123 = plt.fill_between(labels_test, disps_red_mean_hea_0123 - disps_red_std_hea_0123, disps_red_mean_hea_0123 + disps_red_std_hea_0123, alpha=0.35, color="tab:purple", zorder=9)
pqfi = plt.plot(np.sort(labels_test), 1/QFIs, color="C2", label=r"$\frac{1}{I_q}$", linewidth=5, linestyle="solid", zorder=9) # , color="tab:blue"
# pcfi0 = plt.plot(labels_test, CCRBs_mean_0, linewidth=2, zorder=10, linestyle="--")
plt.ylabel(r"$\frac{\Delta^2 M_m^*}{|\partial_h \langle M_m^* \rangle |^2}$" )
plt.xlabel(r"$h$")
plt.grid(zorder=1)
plt.yscale("log")
plt.legend([(pqfi[0])], [r"$\frac{1}{I_q(\psi_h)}$"], framealpha=1)
plt.tight_layout()
# plt.savefig(path + "bfgs-" + file_info + "-mean-var.pdf", transparent=True, bbox_inches='tight')
plt.show()

# %% [markdown]
# # 3 and 4 qubits

# %%
import numpy as np
from numpy import outer, trace, dot, vdot, pi, log2, exp, sin, cos, sqrt, sign, diag, linspace, arange, array, inf, zeros, eye, arccos, arcsin, arctan, mean, std, concatenate, kron, sign, ceil, log, unique
import pickle
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rcParams['font.family']='serif'
matplotlib.rcParams['axes.unicode_minus']=False
matplotlib.rcParams.update({'font.size': 21})
matplotlib.rc('text', usetex=True)

# %%
n_inp = 3
n_layers = 2
n_copies= 1
n_runs = 10
w_ls = 1
w_var = 1e-4
ham_name = "ising_ham"
ansatz_name = "hea"
ansatz_info = ""
n_meas_list = [0]

path = f"/home/investigator/Work/qcnn-var/Results/ising_ham/"
info = f"{ham_name}-{ansatz_name}{ansatz_info}-" + ("l=%d-n=%d-c=%d-m=%s-r=%d-w_ls=%.1f-w_var=%.4f" %(n_layers, n_inp, n_copies, n_meas_list, n_runs, w_ls, w_var)).replace(" ", "")

with open(path + info + ".dict", 'rb') as fp:
    data_dict_loaded_3 = pickle.load(fp)

labels_test = data_dict_loaded_3["labels_test"]
expecs_list_3 = data_dict_loaded_3["expecs_list"]
expecs_der_list_3 = data_dict_loaded_3["expecs_der_list"]
disps_list_3 = data_dict_loaded_3["disps_list"]
CFIs_list_3 = data_dict_loaded_3["CFIs_list"]
QFIs_3 = data_dict_loaded_3["QFIs"]

bias_mean_3 = np.mean((labels_test - expecs_list_3)**2, axis=0)
bias_std_3 = np.std((labels_test - expecs_list_3)**2, axis=0)
disps_red_mean_3 = np.mean(disps_list_3/expecs_der_list_3**2, axis=0)
disps_red_std_3 = np.std(disps_list_3/expecs_der_list_3**2, axis=0)
CCRBs_mean_3 = np.mean(1/CFIs_list_3, axis=0)
CCRBs_std_3 = np.std(1/CFIs_list_3, axis=0)

# %%
n_inp = 4
n_layers = 4
n_copies= 1
n_runs = 10
w_ls = 1
w_var = 1e-4
ham_name = "ising_ham"
ansatz_name = "hea"
ansatz_info = ""
n_meas_list = [0]

path = f"/home/investigator/Work/qcnn-var/Results/ising_ham/"
info = f"{ham_name}-{ansatz_name}{ansatz_info}-" + ("l=%d-n=%d-c=%d-m=%s-r=%d-w_ls=%.1f-w_var=%.4f" %(n_layers, n_inp, n_copies, n_meas_list, n_runs, w_ls, w_var)).replace(" ", "")

with open(path + info + ".dict", 'rb') as fp:
    data_dict_loaded_4_1 = pickle.load(fp)

labels_test = data_dict_loaded_4_1["labels_test"]
expecs_list_4_1 = data_dict_loaded_4_1["expecs_list"]
expecs_der_list_4_1 = data_dict_loaded_4_1["expecs_der_list"]
disps_list_4_1 = data_dict_loaded_4_1["disps_list"]
CFIs_list_4_1 = data_dict_loaded_4_1["CFIs_list"]
QFIs_4_1 = data_dict_loaded_4_1["QFIs"]

bias_mean_4_1 = np.mean((labels_test - expecs_list_4_1)**2, axis=0)
bias_std_4_1 = np.std((labels_test - expecs_list_4_1)**2, axis=0)
disps_red_mean_4_1 = np.mean(disps_list_4_1/expecs_der_list_4_1**2, axis=0)
disps_red_std_4_1 = np.std(disps_list_4_1/expecs_der_list_4_1**2, axis=0)
CCRBs_mean_4_1 = np.mean(1/CFIs_list_4_1, axis=0)
CCRBs_std_4_1 = np.std(1/CFIs_list_4_1, axis=0)

# %%
n_inp = 4
n_layers = 4
n_copies= 1
n_runs = 10
w_ls = 1
w_var = 1e-4
ham_name = "ising_ham"
ansatz_name = "hea"
ansatz_info = ""
n_meas_list = [0, 1, 2, 3]

path = f"/home/investigator/Work/qcnn-var/Results/ising_ham/"
info = f"{ham_name}-{ansatz_name}{ansatz_info}-" + ("l=%d-n=%d-c=%d-m=%s-r=%d-w_ls=%.1f-w_var=%.4f" %(n_layers, n_inp, n_copies, n_meas_list, n_runs, w_ls, w_var)).replace(" ", "")

with open(path + info + ".dict", 'rb') as fp:
    data_dict_loaded_4_4 = pickle.load(fp)

labels_test = data_dict_loaded_4_4["labels_test"]
expecs_list_4_4 = data_dict_loaded_4_4["expecs_list"]
expecs_der_list_4_4 = data_dict_loaded_4_4["expecs_der_list"]
disps_list_4_4 = data_dict_loaded_4_4["disps_list"]
CFIs_list_4_4 = data_dict_loaded_4_4["CFIs_list"]
QFIs_4_4 = data_dict_loaded_4_4["QFIs"]

bias_mean_4_4 = np.mean((labels_test - expecs_list_4_4)**2, axis=0)
bias_std_4_4 = np.std((labels_test - expecs_list_4_4)**2, axis=0)
disps_red_mean_4_4 = np.mean(disps_list_4_4/expecs_der_list_4_4**2, axis=0)
disps_red_std_4_4 = np.std(disps_list_4_4/expecs_der_list_4_4**2, axis=0)
CCRBs_mean_4_4 = np.mean(1/CFIs_list_4_4, axis=0)
CCRBs_std_4_4 = np.std(1/CFIs_list_4_4, axis=0)

# %%
file_info = r"ising-n=(3,4)-c=1-m=(1,4)-w_ls=%.1f-w_var=%.4f" %(w_ls, w_var)

plt.figure(figsize=(6, 3.75))
p3 = plt.plot(labels_test, bias_mean_3, color="gold", linewidth=4, label=r"$n=3$, $m=1$")
p4_1 = plt.plot(labels_test, bias_mean_4_1, color="tab:red", linewidth=4, label=r"$n=4$, $m=1$")
p4_4 = plt.plot(labels_test, bias_mean_4_4, color="tab:blue", linewidth=4, label=r"$n=4$, $m=4$")
plt.xlabel(r"$h$")
plt.ylabel(r"$(\mathsf{h} - h)^2$")
plt.grid()
plt.tight_layout()
plt.legend(fontsize=18, framealpha=1)
plt.savefig(path + file_info + "-mean-est-3-4.pdf", transparent=True, bbox_inches='tight')
plt.show()


plt.figure(figsize=(6, 3.75))
p3 = plt.plot(labels_test, disps_red_mean_3, linewidth=5, color="gold", zorder=10)
pcfi_3 = plt.plot(labels_test, CCRBs_mean_3, linewidth=2, label=r"$\frac{1}{I_c}$, $n=3$, $m=1$", linestyle="--", color="yellow", zorder=10)
pqfi_3 = plt.plot(labels_test, 1/QFIs_3, linewidth=12, color="C2", label=r"$\frac{1}{I_q}$, $n=3$", linestyle="solid", zorder=9) # , color="tab:blue"
plt.ylabel(r"$\frac{\Delta^2 M^*_{m}}{|\partial_h \langle M^*_{m} \rangle |^2}$" )
plt.xlabel(r"$h$")
plt.grid(zorder=1)
# plt.yscale("log")
plt.legend(fontsize=18, framealpha=1)
plt.tight_layout()
plt.savefig(path + file_info + "-mean-var-3.pdf", transparent=True, bbox_inches='tight')
plt.show()

plt.figure(figsize=(6, 3.75))
p4_1 = plt.plot(labels_test, disps_red_mean_4_1, linewidth=6, color="tab:red", zorder=10)
p4_4 = plt.plot(labels_test, disps_red_mean_4_4, linewidth=6, color="tab:blue", zorder=10)
pcfi_4_1 = plt.plot(labels_test, CCRBs_mean_4_1, linewidth=2, zorder=10, linestyle="--", color="coral", label=r"$\frac{1}{I_c}$, $n=4$, $m=1$")
pcfi_4_4 = plt.plot(labels_test, CCRBs_mean_4_4, linewidth=2, zorder=10, linestyle="--", color="cyan", label=r"$\frac{1}{I_c}$, $n=4$, $m=4$")
pqfi_4_4 = plt.plot(labels_test, 1/QFIs_4_4, linewidth=7, color="C2", label=r"$\frac{1}{I_q}$, $n=4$", linestyle="solid", zorder=1) # , color="tab:blue"
plt.ylabel(r"$\frac{\Delta^2 M^*_{m}}{|\partial_h \langle M^*_{m} \rangle |^2}$" )
plt.xlabel(r"$h$")
plt.grid(zorder=1)
# plt.yscale("log")
plt.legend(fontsize=18, framealpha=1)
plt.tight_layout()
plt.savefig(path + file_info + "-mean-var-4.pdf", transparent=True, bbox_inches='tight')
plt.show()
